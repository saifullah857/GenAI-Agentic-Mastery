# %% [markdown]
# ## Tools creation in Langchain

# %%
from langchain.agents import create_agent
from langchain.tools import tool
from dotenv import load_dotenv
import os

# Load .env
load_dotenv()

# Tool
@tool
def get_weather(location: str) -> str:
    """Get the weather for a city."""
    
    return f"The weather in {location} is sunny."


# Create Agent
agent = create_agent(
    model="groq:llama-3.1-8b-instant",
    tools=[get_weather] 
)

# Invoke Agent
response = agent.invoke({
    "messages": [
        ("user", "what is weather in Phool Nagar")
    ]
})

# Print Response
print(response)
# Out:
# {'messages': [HumanMessage(content='what is weather in Phool Nagar', additional_kwargs={}, response_metadata={}, id='63eac0e1-4a98-460b-afa8-d538e7051117'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'vvyb7zs63', 'function': {'arguments': '{"location":"Phool Nagar"}', 'name': 'get_weather'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 219, 'total_tokens': 235, 'completion_time': 0.026645569, 'completion_tokens_details': None, 'prompt_time': 0.017004654, 'prompt_tokens_details': None, 'queue_time': 0.048844475, 'total_time': 0.043650223}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4848f70c04', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e6416-1ea4-72c2-be94-4c68ecf34f05-0', tool_calls=[{'name': 'get_weather', 'args': {'location': 'Phool Nagar'}, 'id': 'vvyb7zs63', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 219, 'output_tokens': 16, 'total_tokens': 235}), ToolMessage(content='The weather in Phool Nagar is sunny.', name='get_weather', id='2f52939d-adda-4d6b-9085-13f6178f71b5', tool_call_id='vvyb7zs63'), AIMessage(content='However, I am unable to verify the correct weather in Phool Nagar.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 254, 'total_tokens': 270, 'completion_time': 0.0279488, 'completion_tokens_details': None, 'prompt_time': 0.018405129, 'prompt_tokens_details': None, 'queue_time': 0.050045189, 'total_time': 0.046353929}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_d9492c3c54', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e6416-223f-7c71-93b4-43edd53ae378-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 254, 'output_tokens': 16, 'total_tokens': 270})]}

# %% [markdown]
# ##

# %% [markdown]
# ## bind tool

# %%
from langchain_groq import ChatGroq
from langchain.tools import tool
from dotenv import load_dotenv

# Load .env
load_dotenv()

# Create Model
model = ChatGroq(
    model="llama-3.1-8b-instant"
)

# Create Tool
@tool
def get_weather(location: str) -> str:
    """Get the weather at a location"""
    
    return f"It's sunny in {location}"


# Bind Tool
model_with_tools = model.bind_tools([get_weather])

# Invoke Model
response = model_with_tools.invoke(
    "What's the weather like in Boston?"
)

print(response)
# Out:
# content='' additional_kwargs={'tool_calls': [{'id': '5emwe8bgh', 'function': {'arguments': '{"location":"Boston"}', 'name': 'get_weather'}, 'type': 'function'}]} response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 220, 'total_tokens': 234, 'completion_time': 0.023114665, 'completion_tokens_details': None, 'prompt_time': 0.045360583, 'prompt_tokens_details': None, 'queue_time': 0.049551092, 'total_time': 0.068475248}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_e09ee421cf', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019e641b-0290-7762-a3a4-42936bcee14f-0' tool_calls=[{'name': 'get_weather', 'args': {'location': 'Boston'}, 'id': '5emwe8bgh', 'type': 'tool_call'}] invalid_tool_calls=[] usage_metadata={'input_tokens': 220, 'output_tokens': 14, 'total_tokens': 234}
